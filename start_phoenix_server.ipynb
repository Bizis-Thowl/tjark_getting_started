# %% [markdown]
# This notebook can be used if no external phoenix server is available.
#
# > Careful: Data and server will only be available while this script runs!

# %%
import phoenix as px

session = px.launch_app()
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Valentin/Desktop/Live Tutorial/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
